# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('1 case/sensor.csv',index_col='timestamp',parse_dates=True).drop('Unnamed: 0',axis=1)

# %%
data=pd.read_csv('3 case/sensor.csv',index_col='timestamp',parse_dates=True).drop('Unnamed: 0',axis=1)
initial=data.copy()
target=data['machine_status']
data=data.drop(['machine_status','sensor_15'],axis=1).dropna(axis=0)
target=target[data.index]

# %%
data=data.drop('sensor_15',axis=1).dropna(axis=0)
target=target[data.index]

# %%
len(target)
# Out:
# 119103

# %%
data.columns
# Out:
# Index(['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04',
#        'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09',
#        'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25',
#        'sensor_26', 'sensor_27', 'sensor_28', 'sensor_29', 'sensor_30',
#        'sensor_31', 'sensor_32', 'sensor_33', 'sensor_34', 'sensor_35',
#        'sensor_36', 'sensor_37', 'sensor_38', 'sensor_39', 'sensor_40',
#        'sensor_41', 'sensor_42', 'sensor_43', 'sensor_44', 'sensor_45',
#        'sensor_46', 'sensor_47', 'sensor_48', 'sensor_49', 'sensor_50',
#        'sensor_51'],
#       dtype='object')

# %%
target.unique()
# Out:
# array(['NORMAL', 'BROKEN', 'RECOVERING'], dtype=object)

# %% [markdown]
# 205836 7 14477

# %%
in_normal = target[target == 'NORMAL'].index
in_broken = target[target == 'BROKEN'].index
in_recovering = target[target == 'RECOVERING'].index
print(len(in_normal),len(in_broken),len(in_recovering))
# Out:
# 116133 5 2965

# %%
plt.figure()
plt.plot(data['sensor_00'],'o')
plt.title('sensor_00 INITIAL')
plt.show()
for i in list(data.columns):
    plt.figure()
    plt.plot(data[i][in_normal],'o',label='in_normal')
    plt.plot(data[i][in_broken],'o',label='in_broken')
    plt.plot(data[i][in_recovering],'o',label='in_recovering')
    plt.title(i)
    plt.show()
